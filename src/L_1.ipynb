# %% [markdown]
# # L1: Automated Project: Planning, Estimation, and Allocation

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note <code>(Kernel Starting)</code>:</b> This notebook takes about 30 seconds to be ready to use. You may start and watch the video while you wait.</p>

# %% [markdown]
# ## Initial Imports

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# Load environment variables
from crewai_utils.helper import load_env
load_env()

import os
import yaml
from crewai import Agent, Task, Crew

# %% [markdown]
# <p style="background-color:#fff6ff; padding:15px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px"> 💻 &nbsp; <b>Access <code>requirements.txt</code> and <code>helper.py</code> files:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Open"</em>. For more help, please see the <em>"Appendix - Tips and Help"</em> Lesson.</p>

# %% [markdown]
# ## Set OpenAI Model

# %%
os.environ['OPENAI_MODEL_NAME'] = 'gpt-4o-mini'

# %% [markdown]
# ## Loading Tasks and Agents YAML files

# %%
# Define file paths for YAML configurations
files = {
    'agents': 'config/agents.yaml',
    'tasks': 'config/tasks.yaml'
}

# Load configurations from YAML files
configs = {}
for config_type, file_path in files.items():
    with open(file_path, 'r') as file:
        configs[config_type] = yaml.safe_load(file)

# Assign loaded configurations to specific variables
agents_config = configs['agents']
tasks_config = configs['tasks']

# %% [markdown]
# ## Create Pydantic Models for Structured Output

# %%
from typing import List
from pydantic import BaseModel, Field

class TaskEstimate(BaseModel):
    task_name: str = Field(..., description="Name of the task")
    estimated_time_hours: float = Field(..., description="Estimated time to complete the task in hours")
    required_resources: List[str] = Field(..., description="List of resources required to complete the task")

class Milestone(BaseModel):
    milestone_name: str = Field(..., description="Name of the milestone")
    tasks: List[str] = Field(..., description="List of task IDs associated with this milestone")

class ProjectPlan(BaseModel):
    tasks: List[TaskEstimate] = Field(..., description="List of tasks with their estimates")
    milestones: List[Milestone] = Field(..., description="List of project milestones")

# %% [markdown]
# ## Create Crew, Agents and Tasks

# %%
# Creating Agents
project_planning_agent = Agent(
  config=agents_config['project_planning_agent']
)

estimation_agent = Agent(
  config=agents_config['estimation_agent']
)

resource_allocation_agent = Agent(
  config=agents_config['resource_allocation_agent']
)

# Creating Tasks
task_breakdown = Task(
  config=tasks_config['task_breakdown'],
  agent=project_planning_agent
)

time_resource_estimation = Task(
  config=tasks_config['time_resource_estimation'],
  agent=estimation_agent
)

resource_allocation = Task(
  config=tasks_config['resource_allocation'],
  agent=resource_allocation_agent,
  output_pydantic=ProjectPlan # This is the structured output we want
)

# Creating Crew
crew = Crew(
  agents=[
    project_planning_agent,
    estimation_agent,
    resource_allocation_agent
  ],
  tasks=[
    task_breakdown,
    time_resource_estimation,
    resource_allocation
  ],
  verbose=True
)
# Out:
# 2025-04-18 15:00:37,892 - 8306001984 - __init__.py-__init__:538 - WARNING: Overriding of current TracerProvider is not allowed

# %% [markdown]
# ## Crew's Inputs

# %%
from IPython.display import display, Markdown

project = 'Website'
industry = 'Technology'
project_objectives = 'Create a website for a small business'
team_members = """
- John Doe (Project Manager)
- Jane Doe (Software Engineer)
- Bob Smith (Designer)
- Alice Johnson (QA Engineer)
- Tom Brown (QA Engineer)
"""
project_requirements = """
- Create a responsive design that works well on desktop and mobile devices
- Implement a modern, visually appealing user interface with a clean look
- Develop a user-friendly navigation system with intuitive menu structure
- Include an "About Us" page highlighting the company's history and values
- Design a "Services" page showcasing the business's offerings with descriptions
- Create a "Contact Us" page with a form and integrated map for communication
- Implement a blog section for sharing industry news and company updates
- Ensure fast loading times and optimize for search engines (SEO)
- Integrate social media links and sharing capabilities
- Include a testimonials section to showcase customer feedback and build trust
"""

# Format the dictionary as Markdown for a better display in Jupyter Lab
formatted_output = f"""
**Project Type:** {project}

**Project Objectives:** {project_objectives}

**Industry:** {industry}

**Team Members:**
{team_members}
**Project Requirements:**
{project_requirements}
"""
# Display the formatted output as Markdown
display(Markdown(formatted_output))
# Out:
# **Project Type:** Website
#
# **Project Objectives:** Create a website for a small business
#
# **Industry:** Technology
#
# **Team Members:**
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
# **Project Requirements:**
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust

# %% [markdown]
# ## Kicking off the crew

# %%
# The given Python dictionary
inputs = {
  'project_type': project,
  'project_objectives': project_objectives,
  'industry': industry,
  'team_members': team_members,
  'project_requirements': project_requirements
}

# Run the crew
result = crew.kickoff(
  inputs=inputs
)
# Out:
# # Agent: The Ultimate Project Planner
# ## Task: Carefully analyze the project_requirements for the Website project and break them down into individual tasks. Define each task's scope in detail, set achievable timelines, and ensure that all dependencies are accounted for:
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust
#
#
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
#
#
#
# # Agent: The Ultimate Project Planner
# ## Final Answer:
# ### Comprehensive Task Breakdown for Website Project
#
# **Project Requirements:**
# 1. Create a responsive design that works well on desktop and mobile devices
# 2. Implement a modern, visually appealing user interface with a clean look
# 3. Develop a user-friendly navigation system with intuitive menu structure
# 4. Include an "About Us" page highlighting the company's history and values
# 5. Design a "Services" page showcasing the business's offerings with descriptions
# 6. Create a "Contact Us" page with a form and integrated map for communication
# 7. Implement a blog section for sharing industry news and company updates
# 8. Ensure fast loading times and optimize for search engines (SEO)
# 9. Integrate social media links and sharing capabilities
# 10. Include a testimonials section to showcase customer feedback and build trust
#
# ### Task Breakdown with Scope, Timelines, Dependencies, and Deliverables
#
# | Task ID | Task Description                                                                                      | Scope                                                                                                   | Assigned To      | Timeline (Days) | Dependencies             | Deliverables                                          |
# |---------|------------------------------------------------------------------------------------------------------|---------------------------------------------------------------------------------------------------------|------------------|-----------------|---------------------------|------------------------------------------------------|
# | 1       | Create a responsive design                                                                           | Design layout for both desktop and mobile, ensuring adaptability across devices.                        | Bob Smith        | 5               | None                      | Responsive wireframes                                   |
# | 2       | Implement modern user interface                                                                       | Develop UI components with up-to-date design trends and a clean aesthetic.                            | Bob Smith        | 5               | Task 1                   | UI design mockups                                      |
# | 3       | Develop user-friendly navigation system                                                              | Organize content into a logical flow and create an intuitive menu structure.                           | Jane Doe         | 4               | Task 2                   | Navigation structure outline                           |
# | 4       | Create "About Us" page                                                                                | Write content highlighting the company's history, mission, and values; design layout.                  | Jane Doe & Bob   | 3               | Task 2                   | Completed "About Us" page                             |
# | 5       | Design "Services" page                                                                                | Showcase services with engaging descriptions and related images.                                        | Jane Doe         | 4               | Task 2                   | Completed "Services" page                             |
# | 6       | Create "Contact Us" page                                                                              | Provide a form for inquiries and integrate a map for location.                                         | Jane Doe         | 3               | Tasks 2 & 3              | Completed "Contact Us" page                           |
# | 7       | Implement blog section                                                                                 | Set up a blog layout, add capability for posts, and integrate content management for updates.          | Jane Doe         | 5               | Task 1, 2                | Functional blog section                               |
# | 8       | Optimize for fast loading and SEO                                                                      | Perform all necessary optimizations for speed and ensure proper SEO practices are applied.             | Jane Doe         | 3               | All previous tasks       | Speed optimization report and SEO audit               |
# | 9       | Integrate social media links                                                                          | Add links and sharing capabilities to all relevant pages.                                               | Jane Doe         | 2               | Task 6                   | Integrated social media functionality                  |
# | 10      | Include testimonials section                                                                           | Collect and display customer feedback; design layout for testimonials.                                 | Jane Doe         | 3               | Task 5                   | Completed testimonials section                         |
# | **Total**  |                                                                                                    |                                                                                                         |                  | **39 Days**      |                           |                                                      |
#
# ### Gantt Chart Visualization
#
# The Gantt chart below outlines the tasks and timelines visually.
#
# ```plaintext
# | Task ID | Task Description                         | Duration | Days     | Effort                       |
# |---------|-----------------------------------------|----------|----------|------------------------------|
# | 1       | Create a responsive design              | 5        | 1-5      | *****(5)                     |
# | 2       | Implement modern UI                     | 5        | 6-10     | *****                        |
# | 3       | Develop navigation system               | 4        | 11-14    | ****                         |
# | 4       | Create "About Us" page                 | 3        | 15-17    | ***                          |
# | 5       | Design "Services" page                 | 4        | 18-21    | ****                         |
# | 6       | Create "Contact Us" page               | 3        | 22-24    | ***                          |
# | 7       | Implement blog section                  | 5        | 25-29    | *****                        |
# | 8       | Optimize for speed and SEO              | 3        | 30-32    | ***                          |
# | 9       | Integrate social media links            | 2        | 33-34    | **                           |
# | 10      | Include testimonials section             | 3        | 35-37    | ***                          |
# ```
#
# ### Project Timeline
# - **Total Project Duration:** 39 Days
# - Project Start Date: [Insert Start Date]
# - Project End Date: [Insert Start Date + 39 Days]
#
# ### Final Notes
# - Ensure constant communication among team members to track progress.
# - Schedule bi-weekly review meetings to evaluate project scope and address any issues immediately.
# - Utilize project management tools for task allocation and progress tracking throughout the duration.
#
# This detailed breakdown ensures that the website project is planned meticulously, allowing for efficient execution and a successful launch aligned with the small business's goals.
#
#
# # Agent: Expert Estimation Analyst
# ## Task: Thoroughly evaluate each task in the Website project to estimate the time, resources, and effort required. Use historical data, task complexity, and available resources to provide a realistic estimation for each task.
#
#
#
# # Agent: Expert Estimation Analyst
# ## Final Answer:
# ### Detailed Estimation Report for Website Project
#
# #### Task Evaluations
#
# 1. **Create a Responsive Design**
#    - **Time Required:** 5 Days
#    - **Resources Needed:** 1 Designer (Bob Smith)
#    - **Effort:** High (5/5)
#    - **Deliverables:** Responsive wireframes
#    - **Risks/Uncertainties:** Device compatibility issues may arise and require additional testing time.
#
# 2. **Implement Modern User Interface**
#    - **Time Required:** 5 Days
#    - **Resources Needed:** 1 Designer (Bob Smith)
#    - **Effort:** High (5/5)
#    - **Deliverables:** UI design mockups
#    - **Risks/Uncertainties:** A change in design trends during development may prompt revisions.
#
# 3. **Develop User-Friendly Navigation System**
#    - **Time Required:** 4 Days
#    - **Resources Needed:** 1 Designer (Jane Doe)
#    - **Effort:** Moderate (4/5)
#    - **Deliverables:** Navigation structure outline
#    - **Risks/Uncertainties:** User testing may reveal navigation complexities requiring adjustments.
#
# 4. **Create "About Us" Page**
#    - **Time Required:** 3 Days
#    - **Resources Needed:** 1 Content Writer (Jane Doe & Bob Smith)
#    - **Effort:** Low (3/5)
#    - **Deliverables:** Completed "About Us" page
#    - **Risks/Uncertainties:** Difficulty in aligning on company values may delay content finalization.
#
# 5. **Design "Services" Page**
#    - **Time Required:** 4 Days
#    - **Resources Needed:** 1 Designer (Jane Doe)
#    - **Effort:** Moderate (4/5)
#    - **Deliverables:** Completed "Services" page
#    - **Risks/Uncertainties:** Changes in service offerings could affect the content required.
#
# 6. **Create "Contact Us" Page**
#    - **Time Required:** 3 Days
#    - **Resources Needed:** 1 Designer (Jane Doe)
#    - **Effort:** Low (3/5)
#    - **Deliverables:** Completed "Contact Us" page
#    - **Risks/Uncertainties:** Potential integration issues with map services.
#
# 7. **Implement Blog Section**
#    - **Time Required:** 5 Days
#    - **Resources Needed:** 1 Content Manager (Jane Doe)
#    - **Effort:** High (5/5)
#    - **Deliverables:** Functional blog section
#    - **Risks/Uncertainties:** Content management tool compatibility issues could delay implementation.
#
# 8. **Optimize for Fast Loading and SEO**
#    - **Time Required:** 3 Days
#    - **Resources Needed:** 1 Developer (Jane Doe)
#    - **Effort:** Moderate (3/5)
#    - **Deliverables:** Speed optimization report and SEO audit
#    - **Risks/Uncertainties:** Unforeseen complexities in optimization processes may require additional time.
#
# 9. **Integrate Social Media Links**
#    - **Time Required:** 2 Days
#    - **Resources Needed:** 1 Developer (Jane Doe)
#    - **Effort:** Low (2/5)
#    - **Deliverables:** Integrated social media functionality
#    - **Risks/Uncertainties:** Changes in the social media API could necessitate adjustments.
#
# 10. **Include Testimonials Section**
#     - **Time Required:** 3 Days
#     - **Resources Needed:** 1 Designer (Jane Doe)
#     - **Effort:** Low (3/5)
#     - **Deliverables:** Completed testimonials section
#     - **Risks/Uncertainties:** Delays in acquiring customer feedback may postpone this task's completion.
#
# #### Summary of Project Timeline
# - **Total Project Duration:** 39 Days
# - **Initial Allocation:** Start on [Insert Start Date] and Deliver by [Insert End Date: Start Date + 39 Days].
#
# #### Summary of Risks and Uncertainties
# - Potential delays in content creation due to revisions and feedback.
# - The possibility of technical issues related to responsive design implementation.
# - Changes in external APIs affecting integration tasks (e.g., maps, social media).
# - Ongoing communication amongst stakeholders is crucial to overcoming these challenges in a timely manner.
#
# This comprehensive estimation report is designed to facilitate an efficient and streamlined project execution, ensuring thorough tracking of tasks and addressing uncertainties proactively. By leveraging historical data and carefully analyzing each task, we can significantly mitigate the risk of budget overruns and delays, paving the way for a successful launch of the website project.
#
#
# # Agent: Resource Allocation Strategist
# ## Task: Strategically allocate tasks for the Website project to team members based on their skills, availability, and current workload. Ensure that each task is assigned to the most suitable team member and that the workload is evenly distributed.
#
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
#
#
#
# # Agent: Resource Allocation Strategist
# ## Final Answer:
# ### Resource Allocation Chart for Website Project
#
# | Task                             | Assigned Team Member | Start Date   | End Date     |
# |----------------------------------|----------------------|--------------|--------------|
# | Create a Responsive Design       | Bob Smith            | [Insert Start Date]          | [Insert End Date + 5 Days]       |
# | Implement Modern User Interface   | Bob Smith            | [Insert End Date + 5 Days] | [Insert End Date + 10 Days]      |
# | Develop User-Friendly Navigation System | Jane Doe            | [Insert End Date + 5 Days] | [Insert End Date + 9 Days]       |
# | Create "About Us" Page          | Jane Doe, Bob Smith  | [Insert End Date + 10 Days]     | [Insert End Date + 13 Days]      |
# | Design "Services" Page          | Jane Doe             | [Insert End Date + 10 Days] | [Insert End Date + 14 Days]      |
# | Create "Contact Us" Page        | Jane Doe             | [Insert End Date + 14 Days] | [Insert End Date + 17 Days]      |
# | Implement Blog Section           | Jane Doe             | [Insert End Date + 14 Days] | [Insert End Date + 19 Days]      |
# | Optimize for Fast Loading and SEO| Jane Doe             | [Insert End Date + 19 Days] | [Insert End Date + 22 Days]      |
# | Integrate Social Media Links     | Jane Doe             | [Insert End Date + 22 Days] | [Insert End Date + 24 Days]      |
# | Include Testimonials Section      | Jane Doe             | [Insert End Date + 24 Days] | [Insert End Date + 27 Days]      |
#
# ### Summary of Allocation Rationale
#
# 1. **Bob Smith (Designer):**
#    - Assigned to "Create a Responsive Design" and "Implement Modern User Interface" due to his high skill in design and the need for focused effort on high-impact deliverables with substantial workload. Both tasks total 10 days.
#
# 2. **Jane Doe (Software Engineer/Designer):**
#    - To optimize her dual skillset, Jane is assigned to:
#      - "Develop User-Friendly Navigation System," which requires navigation design and is moderately demanding.
#      - Following this, she takes on multiple tasks including "Create 'About Us' Page," "Design 'Services' Page,” and "Create 'Contact Us' Page." Each task is strategically spaced to avoid overworking her while maintaining an overlapping engagement with the content tasks.
#      - Furthermore, she is also responsible for the "Implement Blog Section," "Optimize for Fast Loading and SEO," "Integrate Social Media Links," and "Include Testimonials Section." Each of these tasks is designed to keep her engaged throughout, and they collectively cater to her development strengths.
#
# 3. **Workload Distribution:**
#    - The tasks have been carefully distributed to ensure that Bob Smith focuses on high-effort design tasks initially, while Jane Doe handles a mixture of design and development responsibilities. This allows for a balanced workload without overburdening either team member, maximizing the project’s efficiency and progress.
#
# 4. **Completion Timeline:**
#    - The timeline reflects sequential dependencies, ensuring that tasks such as "Create 'About Us' Page," which needs prior design approval, are strategically timed.
#
# This task allocation not only maximizes the team members' strengths but also mitigates risks by ensuring a balanced workload and timely deliverables. Effective communication will be essential in monitoring progress and adjusting timelines as necessary.
#
# By implementing this comprehensive task allocation strategy, we aim to deliver the project successfully while managing risks and uncertainties effectively.

# %% [markdown]
# ## Usage Metrics and Costs

# %% [markdown]
# Let’s see how much it would cost each time if this crew runs at scale.

# %%
import pandas as pd

costs = 0.150 * (crew.usage_metrics.prompt_tokens + crew.usage_metrics.completion_tokens) / 1_000_000
print(f"Total costs: ${costs:.4f}")

# Convert UsageMetrics instance to a DataFrame
df_usage_metrics = pd.DataFrame([crew.usage_metrics.dict()])
df_usage_metrics
# Out:
# Total costs: $0.0025
#    total_tokens  prompt_tokens  completion_tokens  successful_requests
# 0         16600          10300               6300                    9

# %% [markdown]
# ## Result

# %%
result.pydantic.dict()
# Out:
# {'tasks': [{'task_name': 'Create a Responsive Design',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Bob Smith']},
#   {'task_name': 'Implement Modern User Interface',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Bob Smith']},
#   {'task_name': 'Develop User-Friendly Navigation System',
#    'estimated_time_hours': 32.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': "Create 'About Us' Page",
#    'estimated_time_hours': 24.0,
#    'required_resources': ['Jane Doe', 'Bob Smith']},
#   {'task_name': "Design 'Services' Page",
#    'estimated_time_hours': 24.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': "Create 'Contact Us' Page",
#    'estimated_time_hours': 24.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Implement Blog Section',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Optimize for Fast Loading and SEO',
#    'estimated_time_hours': 24.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Integrate Social Media Links',
#    'estimated_time_hours': 16.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Include Testimonials Section',
#    'estimated_time_hours': 24.0,
#    'required_resources': ['Jane Doe']}],
#  'milestones': [{'milestone_name': 'Design Phase Completed',
#    'tasks': ['Create a Responsive Design', 'Implement Modern User Interface']},
#   {'milestone_name': 'Content Completion',
#    'tasks': ['Develop User-Friendly Navigation System',
#     "Create 'About Us' Page",
#     "Design 'Services' Page",
#     "Create 'Contact Us' Page"]},
#   {'milestone_name': 'Development Phase Completed',
#    'tasks': ['Implement Blog Section',
#     'Optimize for Fast Loading and SEO',
#     'Integrate Social Media Links',
#     'Include Testimonials Section']}]}

# %% [markdown]
# ## Inspect further

# %%
tasks = result.pydantic.dict()['tasks']
df_tasks = pd.DataFrame(tasks)

# Display the DataFrame as an HTML table
df_tasks.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_72d24 th {
#   font-size: 120%;
# }
# #T_72d24  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_72d24" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_72d24_level0_col0" class="col_heading level0 col0" >task_name</th>
#       <th id="T_72d24_level0_col1" class="col_heading level0 col1" >estimated_time_hours</th>
#       <th id="T_72d24_level0_col2" class="col_heading level0 col2" >required_resources</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_72d24_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_72d24_row0_col0" class="data row0 col0" >Create a Responsive Design</td>
#       <td id="T_72d24_row0_col1" class="data row0 col1" >40.000000</td>
#       <td id="T_72d24_row0_col2" class="data row0 col2" >['Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_72d24_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_72d24_row1_col0" class="data row1 col0" >Implement Modern User Interface</td>
#       <td id="T_72d24_row1_col1" class="data row1 col1" >40.000000</td>
#       <td id="T_72d24_row1_col2" class="data row1 col2" >['Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_72d24_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_72d24_row2_col0" class="data row2 col0" >Develop User-Friendly Navigation System</td>
#       <td id="T_72d24_row2_col1" class="data row2 col1" >32.000000</td>
#       <td id="T_72d24_row2_col2" class="data row2 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_72d24_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_72d24_row3_col0" class="data row3 col0" >Create 'About Us' Page</td>
#       <td id="T_72d24_row3_col1" class="data row3 col1" >24.000000</td>
#       <td id="T_72d24_row3_col2" class="data row3 col2" >['Jane Doe', 'Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_72d24_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_72d24_row4_col0" class="data row4 col0" >Design 'Services' Page</td>
#       <td id="T_72d24_row4_col1" class="data row4 col1" >24.000000</td>
#       <td id="T_72d24_row4_col2" class="data row4 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_72d24_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_72d24_row5_col0" class="data row5 col0" >Create 'Contact Us' Page</td>
#       <td id="T_72d24_row5_col1" class="data row5 col1" >24.000000</td>
#       <td id="T_72d24_row5_col2" class="data row5 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_72d24_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_72d24_row6_col0" class="data row6 col0" >Implement Blog Section</td>
#       <td id="T_72d24_row6_col1" class="data row6 col1" >40.000000</td>
#       <td id="T_72d24_row6_col2" class="data row6 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_72d24_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_72d24_row7_col0" class="data row7 col0" >Optimize for Fast Loading and SEO</td>
#       <td id="T_72d24_row7_col1" class="data row7 col1" >24.000000</td>
#       <td id="T_72d24_row7_col2" class="data row7 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_72d24_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_72d24_row8_col0" class="data row8 col0" >Integrate Social Media Links</td>
#       <td id="T_72d24_row8_col1" class="data row8 col1" >16.000000</td>
#       <td id="T_72d24_row8_col2" class="data row8 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_72d24_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_72d24_row9_col0" class="data row9 col0" >Include Testimonials Section</td>
#       <td id="T_72d24_row9_col1" class="data row9 col1" >24.000000</td>
#       <td id="T_72d24_row9_col2" class="data row9 col2" >['Jane Doe']</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Inspecting Milestones

# %%
milestones = result.pydantic.dict()['milestones']
df_milestones = pd.DataFrame(milestones)

# Display the DataFrame as an HTML table
df_milestones.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_67d93 th {
#   font-size: 120%;
# }
# #T_67d93  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_67d93" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_67d93_level0_col0" class="col_heading level0 col0" >milestone_name</th>
#       <th id="T_67d93_level0_col1" class="col_heading level0 col1" >tasks</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_67d93_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_67d93_row0_col0" class="data row0 col0" >Design Phase Completed</td>
#       <td id="T_67d93_row0_col1" class="data row0 col1" >['Create a Responsive Design', 'Implement Modern User Interface']</td>
#     </tr>
#     <tr>
#       <th id="T_67d93_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_67d93_row1_col0" class="data row1 col0" >Content Completion</td>
#       <td id="T_67d93_row1_col1" class="data row1 col1" >['Develop User-Friendly Navigation System', "Create 'About Us' Page", "Design 'Services' Page", "Create 'Contact Us' Page"]</td>
#     </tr>
#     <tr>
#       <th id="T_67d93_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_67d93_row2_col0" class="data row2 col0" >Development Phase Completed</td>
#       <td id="T_67d93_row2_col1" class="data row2 col1" >['Implement Blog Section', 'Optimize for Fast Loading and SEO', 'Integrate Social Media Links', 'Include Testimonials Section']</td>
#     </tr>
#   </tbody>
# </table>
